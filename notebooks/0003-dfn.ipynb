# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import sys
sys.path.append("..")

# %%
from stirling.retnet import RetNet as RetNetS
from retnet import GPTR, GPTRConfig, GPTRClassifier
from lra import ListOps

# %%
dataset = ListOps("listops-1000")
dataset.setup()

# %%
train_dataloader = dataset.train_dataloader(batch_size=32)

# %%
[batch[0].shape[1] for batch in train_dataloader]
# Out:
# [1816,
#  2000,
#  1938,
#  1758,
#  1854,
#  1922,
#  1931,
#  1997,
#  1974,
#  1894,
#  1968,
#  1950,
#  1777,
#  1936,
#  1580,
#  1833,
#  1995,
#  1965,
#  1979,
#  1894,
#  1977,
#  1265,
#  1966,
#  1821,
#  1875,
#  1766,
#  1971,
#  1784,
#  1810,
#  1978,
#  1847,
#  1926,
#  1974,
#  1961,
#  1926,
#  1898,
#  1880,
#  1913,
#  1784,
#  1651,
#  1835,
#  1766,
#  1852,
#  1988,
#  1736,
#  1984,
#  1850,
#  1731,
#  1751,
#  1946,
#  1808,
#  1986,
#  1938,
#  1935,
#  1722,
#  1932,
#  1972,
#  1987,
#  1952,
#  1995,
#  1984,
#  1851,
#  1946,
#  1916,
#  1865,
#  1904,
#  1961,
#  1795,
#  1876,
#  1916,
#  1981,
#  1959,
#  1860,
#  1864,
#  1952,
#  1996,
#  1979,
#  1922,
#  1893,
#  1979,
#  1988,
#  1891,
#  1974,
#  1927,
#  1844,
#  1985,
#  1976,
#  1593,
#  1942,
#  1667,
#  1949,
#  1961,
#  1796,
#  1926,
#  1906,
#  1965,
#  1785,
#  1761,
#  1981,
#  1844,
#  1947,
#  1958,
#  1974,
#  1761,
#  1955,
#  1805,
#  1956,
#  1902,
#  1579,
#  1992,
#  1949,
#  1677,
#  1691,
#  1867,
#  1842,
#  1893,
#  1993,
#  1882,
#  1953,
#  1940,
#  1757,
#  1991,
#  1875,
#  1831,
#  1984,
#  1861,
#  1812,
#  1978,
#  1892,
#  1812,
#  1499,
#  1856,
#  1957,
#  1914,
#  1877,
#  1889,
#  1701,
#  1967,
#  1958,
#  1854,
#  1868,
#  1745,
#  1777,
#  1915,
#  1907,
#  1944,
#  1824,
#  1971,
#  1929,
#  1881,
#  1690,
#  1977,
#  1931,
#  1645,
#  1905,
#  1853,
#  1900,
#  1978,
#  1986,
#  1817,
#  1794,
#  1998,
#  1924,
#  1897,
#  1845,
#  1942,
#  1893,
#  1985,
#  1847,
#  2000,
#  1883,
#  1963,
#  1747,
#  1937,
#  1974,
#  1894,
#  1776,
#  1740,
#  1812,
#  1674,
#  1982,
#  1705,
#  1857,
#  1986,
#  1994,
#  1650,
#  1898,
#  1936,
#  1905,
#  1959,
#  1903,
#  2000,
#  1870,
#  1869,
#  1977,
#  1990,
#  1872,
#  1845,
#  1861,
#  1916,
#  1988,
#  1763,
#  1988,
#  1991,
#  1949,
#  1985,
#  1811,
#  1990,
#  1723,
#  1905,
#  1887,
#  1847,
#  1643,
#  1928,
#  1954,
#  1735,
#  1857,
#  1750,
#  1796,
#  1961,
#  1987,
#  1837,
#  1934,
#  1916,
#  1826,
#  1977,
#  1994,
#  1992,
#  1946,
#  1809,
#  1997,
#  1916,
#  1818,
#  1994,
#  1774,
#  1916,
#  1980,
#  1934,
#  1966,
#  1916,
#  1866,
#  1948,
#  1969,
#  1673,
#  1864,
#  1918,
#  1968,
#  1652,
#  1796,
#  1925,
#  1940,
#  1981,
#  1899,
#  1994,
#  1947,
#  1662,
#  1737,
#  1777,
#  1742,
#  1991,
#  1959,
#  1862,
#  1944,
#  1965,
#  1738,
#  1603,
#  1697,
#  1800,
#  1728,
#  1846,
#  1886,
#  1781,
#  1658,
#  1848,
#  1785,
#  1963,
#  1834,
#  1961,
#  1916,
#  1807,
#  1963,
#  1718,
#  1927,
#  1988,
#  1953,
#  1826,
#  1832,
#  1844,
#  1800,
#  1933,
#  1985,
#  1984,
#  1969,
#  1985,
#  1958,
#  1969,
#  1983,
#  1966,
#  1969,
#  1943,
#  1856,
#  1981,
#  1684,
#  1967,
#  1929,
#  1862,
#  1879,
#  1929,
#  1959,
#  1974,
#  1964,
#  1939,
#  1967,
#  1961,
#  1883,
#  1993,
#  1807,
#  1933,
#  1985,
#  1976,
#  1998,
#  1739,
#  1596,
#  1923,
#  1782,
#  1953,
#  1795,
#  1985,
#  1994,
#  1809,
#  1919,
#  1922,
#  1957,
#  1842,
#  1936,
#  1979,
#  1972,
#  1944,
#  1806,
#  1702,
#  1922,
#  1873,
#  1962,
#  1782,
#  1823,
#  1906,
#  1932,
#  1961,
#  1986,
#  1892,
#  1558,
#  1825,
#  1994,
#  1972,
#  1968,
#  1838,
#  1922,
#  1992,
#  1880,
#  1785,
#  1990,
#  1921,
#  1961,
#  1967,
#  1817,
#  1892,
#  1915,
#  1992,
#  1971,
#  1948,
#  1809,
#  1854,
#  1997,
#  1994,
#  1893,
#  1851,
#  1859,
#  1889,
#  1620,
#  1395,
#  1975,
#  1935,
#  1842,
#  1910,
#  1804,
#  1981,
#  1930,
#  1938,
#  1577,
#  1881,
#  1958,
#  1992,
#  1983,
#  1936,
#  1943,
#  1862,
#  1941,
#  1843,
#  1844,
#  1991,
#  1859,
#  1827,
#  1983,
#  1959,
#  1795,
#  1796,
#  1847,
#  1911,
#  1799,
#  1872,
#  1533,
#  1960,
#  1957,
#  1716,
#  1983,
#  1834,
#  1821,
#  1856,
#  1754,
#  1987,
#  1728,
#  1932,
#  1985,
#  1810,
#  1926,
#  1943,
#  1769,
#  1608,
#  1726,
#  1917,
#  1920,
#  1978,
#  1911,
#  1572,
#  2000,
#  1960,
#  1963,
#  1848,
#  1934,
#  1962,
#  1930,
#  1971,
#  1910,
#  1882,
#  1897,
#  1996,
#  1944,
#  1917,
#  1930,
#  1838,
#  1997,
#  1763,
#  1863,
#  1992,
#  1795,
#  1982,
#  1966,
#  1796,
#  1671,
#  1994,
#  1932,
#  1889,
#  1970,
#  1832,
#  1787,
#  1902,
#  1972,
#  1963,
#  1783,
#  1835,
#  1968,
#  1706,
#  1609,
#  1767,
#  1732,
#  2000,
#  1848,
#  1879,
#  1530,
#  1848,
#  1906,
#  1986,
#  1996,
#  1761,
#  1775,
#  1940,
#  1940,
#  1894,
#  1860,
#  1932,
#  1874,
#  1675,
#  1521,
#  2000,
#  1865,
#  1899,
#  1994,
#  1984,
#  1982,
#  1848,
#  1894,
#  1854,
#  1855,
#  1889,
#  1856,
#  2000,
#  1833,
#  1994,
#  1887,
#  1781,
#  1927,
#  1984,
#  1827,
#  1996,
#  1994,
#  1962,
#  1838,
#  1863,
#  1994,
#  1903,
#  1795,
#  1923,
#  1863,
#  1931,
#  1837,
#  1795,
#  1988,
#  1904,
#  1881,
#  1940,
#  1977,
#  1986,
#  1935,
#  1927,
#  1778,
#  1679,
#  1904,
#  1852,
#  1956,
#  1791,
#  1865,
#  1830,
#  1997,
#  1999,
#  1966,
#  1876,
#  1879,
#  1854,
#  1866,
#  1785,
#  1941,
#  1898,
#  1983,
#  1621,
#  1858,
#  1655,
#  1585,
#  1950,
#  1758,
#  1974,
#  1837,
#  1862,
#  1754,
#  1758,
#  1991,
#  1953,
#  1895,
#  1832,
#  1853,
#  1957,
#  1884,
#  1984,
#  1827,
#  1875,
#  1898,
#  1947,
#  1938,
#  1972,
#  1884,
#  1844,
#  1857,
#  1992,
#  1928,
#  1814,
#  1985,
#  1991,
#  1986,
#  1798,
#  1832,
#  1952,
#  1550,
#  1865,
#  1945,
#  1992,
#  1878,
#  1944,
#  1837,
#  1967,
#  1748,
#  1953,
#  1749,
#  1774,
#  1779,
#  1962,
#  1888,
#  1960,
#  1972,
#  1799,
#  1774,
#  1895,
#  1825,
#  1994,
#  1968,
#  1904,
#  1601,
#  2000,
#  1890,
#  1556,
#  1990,
#  1873,
#  1908,
#  1882,
#  1987,
#  1905,
#  1926,
#  1856,
#  1840,
#  1991,
#  1846,
#  1822,
#  2000,
#  1878,
#  1809,
#  1676,
#  1914,
#  1995,
#  1894,
#  1775,
#  1868,
#  1949,
#  1823,
#  1936,
#  1960,
#  1855,
#  1932,
#  1889,
#  1956,
#  1773,
#  1846,
#  1673,
#  1710,
#  1544,
#  1681,
#  1839,
#  1950,
#  1805,
#  1894,
#  1702,
#  1684,
#  1881,
#  1999,
#  1992,
#  1988,
#  1878,
#  1985,
#  1950,
#  1714,
#  1914,
#  1995,
#  1862,
#  1653,
#  1769,
#  1922,
#  1959,
#  1837,
#  1868,
#  1923,
#  1946,
#  1774,
#  1928,
#  1913,
#  1928,
#  1948,
#  1867,
#  1957,
#  1849,
#  1990,
#  1858,
#  1823,
#  1797,
#  1593,
#  1708,
#  1930,
#  1902,
#  1850,
#  1851,
#  1964,
#  1758,
#  1961,
#  1915,
#  1619,
#  1931,
#  1997,
#  1916,
#  1748,
#  1920,
#  1817,
#  1843,
#  1960,
#  1840,
#  1989,
#  1776,
#  1848,
#  1862,
#  1942,
#  1877,
#  1844,
#  1981,
#  1991,
#  1972,
#  1961,
#  1663,
#  1991,
#  1990,
#  1876,
#  1973,
#  1969,
#  1879,
#  1958,
#  1968,
#  1942,
#  1817,
#  1854,
#  1945,
#  1950,
#  1890,
#  1937,
#  1768,
#  1991,
#  1947,
#  1777,
#  1837,
#  1931,
#  1873,
#  1952,
#  1704,
#  1976,
#  1670,
#  1964,
#  1749,
#  1972,
#  1845,
#  1825,
#  1961,
#  1816,
#  1878,
#  1883,
#  1987,
#  1996,
#  1677,
#  1969,
#  1827,
#  1699,
#  1822,
#  1852,
#  1786,
#  1993,
#  1819,
#  1856,
#  1973,
#  1641,
#  1933,
#  1851,
#  1994,
#  1946,
#  1886,
#  1819,
#  1845,
#  1924,
#  1889,
#  1676,
#  1763,
#  1622,
#  1839,
#  1842,
#  1959,
#  1907,
#  1793,
#  1861,
#  1958,
#  1984,
#  1947,
#  1918,
#  1854,
#  1861,
#  1928,
#  1984,
#  1791,
#  1971,
#  1993,
#  1971,
#  1932,
#  1929,
#  1955,
#  1935,
#  1971,
#  1962,
#  1786,
#  1964,
#  1912,
#  1625,
#  1822,
#  1959,
#  1847,
#  1897,
#  1956,
#  1914,
#  1811,
#  1848,
#  1865,
#  1987,
#  1976,
#  1826,
#  1993,
#  1711,
#  1812,
#  1908,
#  1932,
#  1989,
#  1853,
#  1743,
#  1910,
#  1757,
#  1827,
#  1953,
#  1924,
#  1989,
#  1995,
#  1959,
#  1785,
#  1824,
#  1736,
#  1970,
#  1988,
#  1981,
#  1942,
#  1702,
#  1982,
#  1938,
#  1974,
#  1925,
#  1602,
#  1870,
#  1898,
#  1823,
#  1768,
#  1882,
#  1823,
#  1855,
#  1976,
#  1917,
#  1928,
#  1943,
#  1901,
#  1767,
#  1721,
#  1652,
#  1913,
#  1995,
#  1854,
#  1886,
#  1979,
#  1931,
#  1982,
#  1916,
#  1736,
#  1953,
#  1805,
#  1909,
#  1998,
#  1786,
#  1922,
#  1964,
#  1837,
#  1980,
#  1676,
#  1863,
#  1969,
#  1817,
#  1895,
#  1949,
#  1988,
#  1930,
#  1994,
#  1986,
#  1962,
#  1987,
#  1889,
#  1897,
#  1931,
#  1999,
#  1806,
#  1789,
#  1788,
#  1829,
#  1756,
#  1927,
#  1926,
#  1874,
#  1943,
#  1948,
#  1766,
#  1800,
#  1975,
#  1934,
#  1965,
#  1789,
#  1884,
#  1986,
#  1964,
#  1609,
#  1872,
#  1983,
#  1962,
#  1845,
#  1990,
#  1928,
#  1784,
#  1827,
#  1980,
#  1997,
#  1883,
#  1996,
#  1765,
#  1927,
#  1805,
#  1907,
#  1856,
#  1959,
#  1975,
#  1806,
#  1976,
#  1997,
#  1949,
#  1985,
#  1950,
#  1694,
#  1699,
#  1961,
#  1914,
#  1805,
#  1941,
#  1938,
#  1833,
#  1994,
#  1805,
#  1982,
#  1995,
#  1992,
#  1954,
#  1884,
#  1865,
#  1976,
#  1831,
#  1938,
#  1943,
#  1811,
#  1994,
#  1978,
#  1711,
#  1943,
#  1974,
#  1931,
#  1888,
#  1828,
#  1823,
#  1931,
#  1987,
#  1950,
#  1911,
#  1963,
#  1868,
#  1924,
#  1819,
#  1966,
#  1734,
#  1944,
#  1798,
#  1897,
#  1999,
#  1905,
#  1990,
#  1972,
#  1899,
#  1962,
#  1988,
#  1739,
#  1770,
#  1929,
#  1808,
#  ...]

# %%
model = RetNetS(2, 16, 64, 4)

# %%
config = GPTRConfig(vocab_size=2,
                    context_window=None,
                    nclasses=10,
                    embedding_dim=512,
                    nheads=8,
                    nlayers=6,
                    nhidden=2048
                    )
model = GPTRClassifier(config)
